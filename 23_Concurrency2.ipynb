# %% [markdown]
# ### FUTURES
#
# A future, or promise, is something that represents a pending opearion and returns straight away. One can then query their state of completion, or register callbacks to be called on successful completion or error.
#
# Examples Adapted from Fluent Python.

# %%
import time, uuid, functools
def get_thing_maker(secs, item):
    time.sleep(secs)
    return str(uuid.uuid4())+str(item)
get_thing = functools.partial(get_thing_maker, 1)
def get_many(lot):
    counter=0
    for t in lot:
        thing = get_thing(t)
        counter += 1
    return counter
def serial_main(it):
    t0 = time.time()
    count = get_many(it)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %% [markdown]
# #### Serial sleeping

# %%
serial_main(range(20))
# Out:
# 20 things got in 20.06s

# %% [markdown]
# #### concurrent sleeping using threads

# %%
from concurrent import futures
def get_many_threaded1(it):
    workers = 10
    with futures.ThreadPoolExecutor(max_workers=workers) as executor:
        res = executor.map(get_thing, it)
    return len(list(res))
def threaded_main1(it):
    t0 = time.time()
    count = get_many_threaded1(it)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %%
threaded_main1(range(20))
# Out:
# 20 things got in 2.01s

# %% [markdown]
# One might think that the concurrent IO (or sleeping) case is limited by the GIL, but in both cases, the GIL is yielded. Thus there is no waiting around.
#
# The GIL is harmless if code is being run in the context of python library IO or code running in properly coded C extensions like numpy.  The time.sleep() function also releases the GIL. Python threads are totally usable in I/O-bound applications.

# %% [markdown]
# ### Threads
#
# threads vs processes
#
# On linux
#
# - processes created by fork()
# - have a primary thread
# - thread is the unit of execution
# - process is a container, can have more threads
# - can be scheduled across different cores/cpus
#
# ```c
# int pid;
# int status = 0;
# /* fork returns pid of child to parent and 0 to child*/
# if (pid = fork()) {
#     /* parent code */
#     pid = wait(&status);
#     /*wait returns child pid and status*/
# } else {
#     /* child  code*/
#     exit(status);
# }
# ```
#
# - threads in a process share same address space (share it entirely)
# - thread abstraction decouples resource allocation from control
# - defines a single sequential execution stream with PC, stack, register values
# - process handles: address space, global variables, open files, child processes, pending alarms, signals and signal handlers, accounting info
# - thread handles program counter, registers, stack, and state
# - user vs kernel threads

# %%
def fib(n):
    return fib(n - 1) + fib(n - 2) if n > 1 else n

# %%
from threading import Thread
from time import sleep
from time import time


def sleepy(): #like io
    i=0
    while i < 10:
        print("{} -- {} Sleepy!".format(i, int(time())), flush=True)
        sleep(3)
        i += 1


def cpuy():
    for i in range(35):
        val = fib(i)
        print("fib({}) is {}".format(i, val))

def cpuy2():
    for i in range(35):
        val = fib(i)
        print("cpuy2 fib({}) is {}".format(i, val))
        
def main():
    # Second thread will print the hello message. Starting as a daemon means
    # the thread will not prevent the process from exiting.
    start = time()
    cpuy()
    cpuy2()
    print("serial elapsed:", time() - start)
    start=time()
    #t = Thread(target=sleepy)
    #t.start()
    t2 = Thread(target=cpuy2)
    t2.start()
    # Main thread will read and process input
    cpuy()
    print("thread elapsed:", time() - start)
if __name__ == '__main__':
    main()
# Out:
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# fib(19) is 4181
# fib(20) is 6765
# fib(21) is 10946
# fib(22) is 17711
# fib(23) is 28657
# fib(24) is 46368
# fib(25) is 75025
# fib(26) is 121393
# fib(27) is 196418
# fib(28) is 317811
# fib(29) is 514229
# fib(30) is 832040
# fib(31) is 1346269
# fib(32) is 2178309
# fib(33) is 3524578
# fib(34) is 5702887
# cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# cpuy2 fib(19) is 4181
# cpuy2 fib(20) is 6765
# cpuy2 fib(21) is 10946
# cpuy2 fib(22) is 17711
# cpuy2 fib(23) is 28657
# cpuy2 fib(24) is 46368
# cpuy2 fib(25) is 75025
# cpuy2 fib(26) is 121393
# cpuy2 fib(27) is 196418
# cpuy2 fib(28) is 317811
# cpuy2 fib(29) is 514229
# cpuy2 fib(30) is 832040
# cpuy2 fib(31) is 1346269
# cpuy2 fib(32) is 2178309
# cpuy2 fib(33) is 3524578
# cpuy2 fib(34) is 5702887
# serial elapsed: 15.278671979904175
# cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# cpuy2 fib(19) is 4181
# cpuy2 fib(20) is 6765
# fib(19) is 4181
# fib(20) is 6765
# cpuy2 fib(21) is 10946
# fib(21) is 10946
# cpuy2 fib(22) is 17711
# fib(22) is 17711cpuy2 fib(23) is 28657
#
# fib(23) is 28657
# cpuy2 fib(24) is 46368
# fib(24) is 46368cpuy2 fib(25) is 75025
#
# fib(25) is 75025cpuy2 fib(26) is 121393
#
# fib(26) is 121393
# cpuy2 fib(27) is 196418
# fib(27) is 196418
# cpuy2 fib(28) is 317811
# fib(28) is 317811
# cpuy2 fib(29) is 514229
# fib(29) is 514229
# cpuy2 fib(30) is 832040
# fib(30) is 832040
# cpuy2 fib(31) is 1346269
# fib(31) is 1346269
# cpuy2 fib(32) is 2178309
# fib(32) is 2178309
# cpuy2 fib(33) is 3524578
# fib(33) is 3524578
# cpuy2 fib(34) is 5702887
# fib(34) is 5702887
# thread elapsed: 17.12599205970764

# %% [markdown]
# ### Processes with concurrent futures.
#
# CPU based processing wont release the gil, and is thus best done in a separate process. For illustration, we show what this looks like.

# %%
import time
def get_many_process(it, workers=None):
    if workers:
        with futures.ProcessPoolExecutor(max_workers=workers) as executor:
            res = executor.map(get_thing, it)
    else:
        with futures.ProcessPoolExecutor() as executor:
            res = executor.map(get_thing, it)
    return len(list(res))

def process_main(it, workers=None):
    t0 = time.time()
    count = get_many_process(it, workers)
    elapsed = time.time() - t0
    msg = '\n{} things got in {:.2f}s' 
    print(msg.format(count, elapsed))

# %%
process_main(range(20))
# Out:
# 20 things got in 3.05s

# %%
process_main(range(20), workers=10)
# Out:
# 20 things got in 2.05s

# %%
print(__name__)
# Out:
# __main__

# %%
import multiprocessing
start = time.time()
p=multiprocessing.Process(target=cpuy2)
p.start()
cpuy()
p.join()
print("mp elapsed:", time.time() - start)
# Out:
# fib(0) is 0
# fib(1) is 1
# fib(2) is 1
# fib(3) is 2
# fib(4) is 3
# fib(5) is 5
# fib(6) is 8
# fib(7) is 13
# fib(8) is 21
# fib(9) is 34
# fib(10) is 55
# fib(11) is 89
# fib(12) is 144
# fib(13) is 233
# fib(14) is 377
# fib(15) is 610
# fib(16) is 987
# fib(17) is 1597
# fib(18) is 2584
# fib(19) is 4181
# fib(20) is 6765
# fib(21) is 10946
# fib(22) is 17711
# fib(23) is 28657
# fib(24) is 46368cpuy2 fib(0) is 0
# cpuy2 fib(1) is 1
# cpuy2 fib(2) is 1
# cpuy2 fib(3) is 2
# cpuy2 fib(4) is 3
# cpuy2 fib(5) is 5
# cpuy2 fib(6) is 8
# cpuy2 fib(7) is 13
# cpuy2 fib(8) is 21
# cpuy2 fib(9) is 34
# cpuy2 fib(10) is 55
# cpuy2 fib(11) is 89
# cpuy2 fib(12) is 144
# cpuy2 fib(13) is 233
# cpuy2 fib(14) is 377
# cpuy2 fib(15) is 610
# cpuy2 fib(16) is 987
# cpuy2 fib(17) is 1597
# cpuy2 fib(18) is 2584
# cpuy2 fib(19) is 4181
# cpuy2 fib(20) is 6765
# cpuy2 fib(21) is 10946
# cpuy2 fib(22) is 17711
# cpuy2 fib(23) is 28657
#
# fib(25) is 75025
# fib(26) is 121393cpuy2 fib(24) is 46368
# cpuy2 fib(25) is 75025
#
# fib(27) is 196418cpuy2 fib(26) is 121393
#
# fib(28) is 317811cpuy2 fib(27) is 196418
#
# fib(29) is 514229cpuy2 fib(28) is 317811
#
# fib(30) is 832040cpuy2 fib(29) is 514229
#
# fib(31) is 1346269cpuy2 fib(30) is 832040
# cpuy2 fib(31) is 1346269
#
# fib(32) is 2178309cpuy2 fib(32) is 2178309
#
# fib(33) is 3524578cpuy2 fib(33) is 3524578
#
# fib(34) is 5702887cpuy2 fib(34) is 5702887
#
# mp elapsed: 7.7354230880737305

# %%
input('>')
# Out:
# >a
# 'a'

# %% [markdown]
# ### sockets
#
# - distinction between "client socket" and "server socket"
# - default `socket.socket(family=AF_INET, type=SOCK_STREAM, proto=0, fileno=None)`
# - server socket sits and creates client sockets
# - non-blocking sockets and the `select` system call
#
# Read: https://docs.python.org/3.5/howto/sockets.html

# %% [markdown]
# ### Writing a web page fetcher
#
# We'll eventually use the asyncio module to play with web page fetching and crawling, but lets build up to that by writing a simple fetcher. We'll start with blocking, then move to non-blocking, and finally to co-routines, and even more finally to `yield from` based co-routines.
#
# Adapted from http://aosabook.org/en/500L/a-web-crawler-with-asyncio-coroutines.html

# %% [markdown]
# #### Blocking fetch

# %%
import socket
def fetch(host, url):
    sock = socket.socket()
    sock.connect((host, 80))
    request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(url, host)
    sock.send(request.encode('ascii'))
    response = b''
    chunk = sock.recv(4096)
    while chunk:
        response += chunk
        chunk = sock.recv(4096)
    return response

# %%
from IPython.display import HTML, IFrame
HTML(str(fetch("www.example.com","/")))
# Out:
# b'HTTP/1.0 200 OK\r\nCache-Control: max-age=604800\r\nContent-Type: text/html\r\nDate: Sat, 16 Apr 2016 21:19:31 GMT\r\nEtag: "359670651+gzip+ident"\r\nExpires: Sat, 23 Apr 2016 21:19:31 GMT\r\nLast-Modified: Fri, 09 Aug 2013 23:54:35 GMT\r\nServer: ECS (bos/F56E)\r\nVary: Accept-Encoding\r\nX-Cache: HIT\r\nx-ec-custom-error: 1\r\nContent-Length: 1270\r\nConnection: close\r\n\r\n<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 50px;\n        background-color: #fff;\n        border-radius: 1em;\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        body {\n            background-color: #fff;\n        }\n        div {\n            width: auto;\n            margin: 0 auto;\n            border-radius: 0;\n            padding: 1em;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is established to be used for illustrative examples in documents. You may use this\n    domain in examples without prior coordination or asking for permission.</p>\n    <p><a href="http://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %% [markdown]
# #### Basic non-blocking

# %%
host="www.example.com"
url="/"
request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(url, host)
encoded = request.encode('ascii')
sock = socket.socket()
sock.setblocking(False)
try:
    sock.connect(('xkcd.com', 80))
except BlockingIOError:
    pass
while True:
    try:
        sock.send(encoded)
        break  # Done.
    except OSError as e:
        pass

print('sent')
# Out:
# sent

# %% [markdown]
# This has only been implemented partially. Notice how the `sock.send` spins in a loop.
#
# This eats cycles. the solution is to use select/kqueue/epoll from a small number of connections to a large number of them. The basic idea behind `select` is to wait for an event to occur on a small set of non-blocking sokets.
#
# We'll use python's `DefaultSelector`, an addition from python 3.4 that automatically chooses the "best" select like implementation on your system.

# %%
from selectors import DefaultSelector, EVENT_WRITE
from time import time
selector = DefaultSelector()
host="www.example.com"
sock = socket.socket()
sock.setblocking(False)
try:
    sock.connect((host, 80))
except BlockingIOError:
    pass

def connected():
    selector.unregister(sock.fileno())
    print('connected!', flush=True)

selector.register(sock.fileno(), EVENT_WRITE, connected)
# Out:
# SelectorKey(fileobj=77, fd=77, events=2, data=<function connected at 0x1075f0c80>)

# %% [markdown]
# `connected` is the **callback** run when the connection happens.

# %%
def loop():
    start = time()
    while True:
        if time() - start > 10:
            break
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback()

# %% [markdown]
# Such a loop is called an "event loop". An async frameworkhas two parts: (a) such an event loop and (b) non-blocking sockets. It all runs on one thread. This is a system, it should be obvious for I/O bound problems.
#
# What have we demonstrated already? We showed how to begin an operation and execute a callback when the operation is ready. An async framework builds on the two features we have shown—non-blocking sockets and the event loop—to run concurrent operations on a single thread.
#
# Guido:
# >We have achieved "concurrency" here, but not what is traditionally called "parallelism". What asynchronous I/O is right for, is applications with many slow or sleepy connections with infrequent events.

# %%
loop() #loop will destruct after 10 secs
# Out:
# connected!

# %% [markdown]
# #### async with response reading

# %%
from selectors import DefaultSelector, EVENT_READ, EVENT_WRITE

selector = DefaultSelector()
class Fetcher:
    def __init__(self, host, url, level=0):
        self.response = b''  # Empty array of bytes.
        self.host = host
        self.url = url
        self.sock = None
        
    # Method on Fetcher class.
    def fetch(self):
        self.sock = socket.socket()
        self.sock.setblocking(False)
        try:
            self.sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        # Register next callback.
        selector.register(self.sock.fileno(),
                          EVENT_WRITE,
                          self.connected)

    def connected(self, key, mask):
        print('connected!', flush=True)
        selector.unregister(key.fd)
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        self.sock.send(request.encode('ascii'))

        # Register the next callback.
        selector.register(key.fd,
                          EVENT_READ,
                          self.read_response)
        
    def read_response(self, key, mask):
        global stopped
        
        chunk = self.sock.recv(128)  # USUALLY 4k chunk size, here small
        if chunk:
            print("read chunk", flush=True)
            self.response += chunk
        else:
            print("all read", flush=True)
            selector.unregister(key.fd)  # Done reading.
            stopped=True
            
stopped = False

def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback(event_key, event_mask)
        #do fibonacci

# %%
fetcher = Fetcher('xkcd.com', '/353/')
fetcher.fetch()
loop()
# Out:
# connected!
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# read chunk
# all read

# %% [markdown]
# You can see how the control-flow is chained together by having the connected callback do the resposing. Beyond a 2-3 ladder, this gets confusing and onerous (see some node.js code). As compared to a blocking program, where the continuation of the program is stored and adressed via the instruction pointer in a sequential fashiom, here the cintinuation is stored by registering the callbacks.'
#
# Since the current frame is popped out of the stack, exceptions have a hard time figuring the origin This is called stack-ripping.
#
# So, even apart from the long debate about the relative efficiencies of multithreading and async, there is this other debate regarding which is more error-prone: threads are susceptible to data races if you make a mistake synchronizing them, but callbacks are stubborn to debug due to stack ripping. And within a bit, we get callback soup.
#
# https://thesynchronousblog.wordpress.com/tag/stack-ripping/
#
# Threads seem to offer a more natural way of programming as the programmer with all state in thread’s single stack.

# %% [markdown]
# So why not use them. As we said last time: synchronization and overhead.
#
# But we can do better with Coroutines!
#
# Guido:
# >We entice you with a promise. It is possible to write asynchronous code that combines the efficiency of callbacks with the classic good looks of multithreaded programming. This combination is achieved with a pattern called "coroutines". Using Python 3.4's standard asyncio library, and a package called "aiohttp", fetching a URL in a coroutine is very direct7:
#
#     @asyncio.coroutine
#     def fetch(self, url):
#         response = yield from self.session.get(url)
#         body = yield from response.read()
#
# In 3.5 its even more clear:
#
#     async def fetch(self, url):
#         response = await self.session.get(url)
#         body = await response.read()

# %% [markdown]
# ### Back to the Future with co-routines

# %%
from selectors import DefaultSelector, EVENT_READ, EVENT_WRITE
import socket
selector = DefaultSelector()

# %% [markdown]
# The future, as you might expect is something with callbacks...

# %%
class MyFuture:
    def __init__(self):
        self.result = None
        self._callbacks = []

    def add_done_callback(self, fn):
        self._callbacks.append(fn)

    def set_result(self, result):
        self.result = result
        for fn in self._callbacks:
            fn(self)

# %% [markdown]
# We need a "main" to yield to.

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        #resolves the future by setting a result on it
        def on_connected():
            print('on connected cb ran', flush=True)
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future", flush=True)
        yield f#this makes it look like fetch has returned the "future"
        #bit we have not lost the state (or have to have carried it in obj)
        #a send in will continue us here
        print('we were connected! now back in gen', flush=True)
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        sock.send(request.encode('ascii'))
        while True:
            print("in loop")
            #now create a new future for the data-recieving call
            f = MyFuture()
            def on_response():
                chunky = sock.recv(4096)  # 4k chunk size.
                f.set_result(chunky)
            selector.register(sock.fileno(),
                              EVENT_READ,
                              on_response)
            #now to restart the gen, we will from the main
            #throw the data right back in
            chunk = yield f
            selector.unregister(sock.fileno())
            if chunk:
                print("len(chunk)",len(chunk))
                self.response += chunk
            else:
                print("all read")
                stopped= True
                break

# %%
#But when the future resolves, what resumes the generator? We need a coroutine driver. Let us call it "task":
#(this is our main)
class Task:
    def __init__(self, coro):
        self.coro = coro
        f = MyFuture()
        print(">>sending none to initial future",f)
        f.set_result(None)
        print("...stepping")
        self.step(f)
        print(">>>after priming")

    def step(self, future):
        try:
            print("sending", type(future.result))
            next_future = self.coro.send(future.result)
            print('got next future', next_future)

        except StopIteration:
            print("si")
            return None
        next_future.add_done_callback(self.step)

# %%
stopped=False
def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback()

# %%
fetcher = Fetcher('/353/', 'xkcd.com')
Task(fetcher.fetch())
stopped=False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x10761ac18>
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x10761ac88>
# >>>after priming
# on connected cb ran
# sending <class 'NoneType'>
# we were connected! now back in gen
# in loop
# got next future <__main__.MyFuture object at 0x10761ac18>
# sending <class 'bytes'>
# len(chunk) 1384
# in loop
# got next future <__main__.MyFuture object at 0x10761ab00>
# sending <class 'bytes'>
# len(chunk) 1384
# in loop
# got next future <__main__.MyFuture object at 0x10761ad68>
# sending <class 'bytes'>
# len(chunk) 2768
# in loop
# got next future <__main__.MyFuture object at 0x10761ad30>
# sending <class 'bytes'>
# len(chunk) 2005
# in loop
# got next future <__main__.MyFuture object at 0x10761add8>
# sending <class 'bytes'>
# all read
# si

# %% [markdown]
# #### Refactoring using generators

# %%
#But when the future resolves, what resumes the generator? We need a coroutine driver. Let us call it "task":
#(this is our main)
class Task:
    def __init__(self, coro):
        self.coro = coro
        f = MyFuture()
        print(">>sending none to initial future",f)
        f.set_result(None)
        print("...stepping")
        self.step(f)
        print(">>>after priming")

    def step(self, future):
        try:
            print("sending", type(future.result))
            next_future = self.coro.send(future.result)
            print('got next future', next_future)

        except StopIteration:
            print("si")
            return None
        next_future.add_done_callback(self.step)

# %%
def read(sock):
    f = MyFuture()

    def on_readable():
        f.set_result(sock.recv(4096))

    selector.register(sock.fileno(), EVENT_READ, on_readable)
    chunk = yield f  # Read one chunk.
    selector.unregister(sock.fileno())
    return chunk

# %%
def read_all(sock):
    global stopped
    response = []
    # Read whole response.
    chunk = yield from read(sock)
    while chunk:
        response.append(chunk)
        chunk = yield from read(sock)
    stopped=True
    return b''.join(response)

# %% [markdown]
# >If you squint and make the yield from statements disappear it looks like  conventional functions doing blocking I/O. But in fact, read and read_all are coroutines. Yielding from read pauses read_all until the I/O completes. While read_all is paused, asyncio's event loop does other work and awaits other I/O events; read_all is resumed with the result of read on the next loop tick once its event is ready.

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        def on_connected():
            print('on connected cb ran')
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future")
        yield f
        print('connected!')
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: xkcd.com\r\n\r\n'.format(self.url)
        sock.send(request.encode('ascii'))
        yield from read_all(sock)

# %%
fetcher = Fetcher('/353/', 'xkcd.com')
Task(fetcher.fetch())
stopped = False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x10762b240>
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x10762b2b0>
# >>>after priming
# on connected cb ran
# sending <class 'NoneType'>
# connected!
# got next future <__main__.MyFuture object at 0x10762b2e8>
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x10762b278>
# sending <class 'bytes'>
# si

# %% [markdown]
# ![](http://aosabook.org/en/500L/crawler-images/yield-from.png)
#
# There is one yield left amongst the yield froms. For consistency, this can be fixed...it also lets us change implementations under the hood..

# %%
def read(sock):
    f = MyFuture()

    def on_readable():
        f.set_result(sock.recv(4096))

    selector.register(sock.fileno(), EVENT_READ, on_readable)
    chunk = yield from f  # Read one chunk.
    selector.unregister(sock.fileno())
    return chunk

# %%
class MyFuture:
    def __init__(self):
        self.result = None
        self._callbacks = []

    def add_done_callback(self, fn):
        self._callbacks.append(fn)

    def set_result(self, result):
        self.result = result
        print("cblist", self._callbacks)
        for fn in self._callbacks:
            fn(self)
            
    def __iter__(self):
        yield self
        return self.result

# %%
class Fetcher:
    
    def __init__(self, url, host):
        self.url = url
        self.host = host
        self.response = b''  # Empty array of bytes.

        
    def fetch(self):
        global stopped
        sock = socket.socket()

        sock.setblocking(False)
        try:
            sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        f = MyFuture()

        def on_connected():
            print('on connected cb ran')
            f.set_result(None)
        
        
        
        selector.register(sock.fileno(),
                          EVENT_WRITE,
                          on_connected)
        print("about to yield connection future")
        yield from f
        print('connected!')
        selector.unregister(sock.fileno())
        request = 'GET {} HTTP/1.0\r\nHost: xkcd.com\r\n\r\n'.format(self.url)
        sock.send(request.encode('ascii'))
        yield from read_all(sock)

# %%
fetcher = Fetcher('/353/','xkcd.com')
Task(fetcher.fetch())
stopped = False
loop()
# Out:
# >>sending none to initial future <__main__.MyFuture object at 0x10761af98>
# cblist []
# ...stepping
# sending <class 'NoneType'>
# about to yield connection future
# got next future <__main__.MyFuture object at 0x10761af60>
# >>>after priming
# on connected cb ran
# cblist [<bound method Task.step of <__main__.Task object at 0x10761ae80>>]
# sending <class 'NoneType'>
# connected!
# got next future <__main__.MyFuture object at 0x10761a630>
# cblist [<bound method Task.step of <__main__.Task object at 0x10761ae80>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x10761ab00>
# cblist [<bound method Task.step of <__main__.Task object at 0x10761ae80>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x10761af98>
# cblist [<bound method Task.step of <__main__.Task object at 0x10761ae80>>]
# sending <class 'bytes'>
# got next future <__main__.MyFuture object at 0x10761a630>
# cblist [<bound method Task.step of <__main__.Task object at 0x10761ae80>>]
# sending <class 'bytes'>
# si

# %% [markdown]
# ## Lab
#
# Implement a URL fetcher using Beautiful Soup in the callback version. We will implement a similar one using coroutines on wednesday.
#
# The implimentation will extend the read_response method by parsing for URL's using `bs4` . Start by creating globals:
# ```
# urls_todo = set(['/'])
# seen_urls = set(['/'])
# ```
#
# then:
#
# ```
# links = self.parse_links()#write this
# ```
# (using self.response)
#
# Then use the set `difference` method  to add new links to `urls_todo` and recursively set up a `Fetcher` instance.
#
# Now update the `seen_urls` and `urls_todo` thus:
# ```
# seen_urls.update(links)
# urls_todo.remove(self.url)
# if not urls_todo:
#     stopped = True
# ```

# %%
from bs4 import BeautifulSoup

# %%
selector = DefaultSelector()
class Fetcher:
    def __init__(self, host, url, level=0):
        self.response = b''  # Empty array of bytes.
        self.host = host
        self.url = url
        self.sock = None
        
    # Method on Fetcher class.
    def fetch(self):
        self.sock = socket.socket()
        self.sock.setblocking(False)
        try:
            self.sock.connect((self.host, 80))
        except BlockingIOError:
            pass

        # Register next callback.
        selector.register(self.sock.fileno(),
                          EVENT_WRITE,
                          self.connected)

    def connected(self, key, mask):
        #print('connected!', flush=True)
        selector.unregister(key.fd)
        request = 'GET {} HTTP/1.0\r\nHost: {}\r\n\r\n'.format(self.url, self.host)
        self.sock.send(request.encode('ascii'))

        # Register the next callback.
        selector.register(key.fd,
                          EVENT_READ,
                          self.read_response)
        
    def read_response(self, key, mask):
        global stopped
        #global urls_todo
        #global seen_urls
        
        # I upped the chunk size here
        chunk = self.sock.recv(2048)  # USUALLY 4k chunk size, here small
        if chunk:
            #print("read chunk", flush=True)
            self.response += chunk
        else:
            selector.unregister(key.fd)  # Done reading.
            print("Unregistered from %s%s" % (self.host, self.url), flush=True)
            
            links = set(self.parse_links())
            
            for link in links.difference(seen_urls):
                urls_todo.add(link)
                Fetcher(self.host, link).fetch()
            
            seen_urls.update(links)
            urls_todo.remove(self.url)

            
            if not urls_todo:
                stopped = True
            
    def parse_links(self):
        bs = BeautifulSoup(self.response, 'html.parser')
        link_data = bs.find_all('a', href=True)
        links = []
        for a_link in link_data:
            # Let's only retrieve urls that are on the same host for the moment
            if a_link['href'][0] == '/':
                links.append(a_link['href'])
        return links
        
        
stopped = False
def loop():
    while not stopped:
        events = selector.select()
        for event_key, event_mask in events:
            callback = event_key.data
            callback(event_key, event_mask)
            
urls_todo = set(['/'])
seen_urls = set(['/'])
fetcher = Fetcher('xkcd.com', '/')
fetcher.fetch()
loop()
# Out:
# Unregistered from xkcd.com/
# Unregistered from xkcd.com/1/
# Unregistered from xkcd.com/about
# Unregistered from xkcd.com//c.xkcd.com/random/comic/
# Unregistered from xkcd.com/archive
# Unregistered from xkcd.com/rss.xml
# Unregistered from xkcd.com/license.html
# Unregistered from xkcd.com/atom.xml
# Unregistered from xkcd.com/1667/
# Unregistered from xkcd.com/2/
# Unregistered from xkcd.com/1668/
# Unregistered from xkcd.com/1666/
# Unregistered from xkcd.com/3/
# Unregistered from xkcd.com/1665/
# Unregistered from xkcd.com/4/
# Unregistered from xkcd.com/1664/
# Unregistered from xkcd.com/5/
# Unregistered from xkcd.com/1663/
# Unregistered from xkcd.com/6/
# Unregistered from xkcd.com/1662/
# Unregistered from xkcd.com/7/
# Unregistered from xkcd.com/1661/
# Unregistered from xkcd.com/8/
# Unregistered from xkcd.com/1660/
# Unregistered from xkcd.com/9/
# Unregistered from xkcd.com/1659/
# Unregistered from xkcd.com/10/
# Unregistered from xkcd.com/1658/
# Unregistered from xkcd.com/11/
# Unregistered from xkcd.com/1657/
# Unregistered from xkcd.com/12/
# Unregistered from xkcd.com/1656/
# Unregistered from xkcd.com/13/
# Unregistered from xkcd.com/1655/
# Unregistered from xkcd.com/1654/
# Unregistered from xkcd.com/14/
# Unregistered from xkcd.com/1653/
# Unregistered from xkcd.com/15/
# Unregistered from xkcd.com/1652/
# Unregistered from xkcd.com/16/
# Unregistered from xkcd.com/1651/
# Unregistered from xkcd.com/17/
# Unregistered from xkcd.com/1650/
# Unregistered from xkcd.com/18/
# Unregistered from xkcd.com/1649/
# Unregistered from xkcd.com/19/
# Unregistered from xkcd.com/1648/
# Unregistered from xkcd.com/20/
# Unregistered from xkcd.com/1647/
# Unregistered from xkcd.com/21/
# Unregistered from xkcd.com/22/
# Unregistered from xkcd.com/1646/
# Unregistered from xkcd.com/23/
# Unregistered from xkcd.com/1645/
# Unregistered from xkcd.com/24/
# Unregistered from xkcd.com/1644/
# Unregistered from xkcd.com/25/
# Unregistered from xkcd.com/1643/
# Unregistered from xkcd.com/26/
# Unregistered from xkcd.com/1642/
# Unregistered from xkcd.com/27/
# Unregistered from xkcd.com/1641/
# Unregistered from xkcd.com/28/
# Unregistered from xkcd.com/1640/
# Unregistered from xkcd.com/29/
# Unregistered from xkcd.com/1639/
# Unregistered from xkcd.com/30/
# Unregistered from xkcd.com/1638/
# Unregistered from xkcd.com/31/
# Unregistered from xkcd.com/1637/
# Unregistered from xkcd.com/32/
# Unregistered from xkcd.com/1636/
# Unregistered from xkcd.com/33/
# Unregistered from xkcd.com/1635/
# Unregistered from xkcd.com/34/
# Unregistered from xkcd.com/1634/
# Unregistered from xkcd.com/35/
# Unregistered from xkcd.com/1633/
# Unregistered from xkcd.com/36/
# Unregistered from xkcd.com/1632/
# Unregistered from xkcd.com/37/
# Unregistered from xkcd.com/1631/
# Unregistered from xkcd.com/38/
# Unregistered from xkcd.com/1630/
# Unregistered from xkcd.com/39/
# Unregistered from xkcd.com/1629/
# Unregistered from xkcd.com/40/
# Unregistered from xkcd.com/1628/
# Unregistered from xkcd.com/41/
# Unregistered from xkcd.com/1627/
# Unregistered from xkcd.com/42/
# Unregistered from xkcd.com/1626/
# Unregistered from xkcd.com/43/
# Unregistered from xkcd.com/1625/
# Unregistered from xkcd.com/44/
# Unregistered from xkcd.com/1624/
# Unregistered from xkcd.com/45/
# Unregistered from xkcd.com/1623/
# Unregistered from xkcd.com/46/
# Unregistered from xkcd.com/1622/
# Unregistered from xkcd.com/47/
# Unregistered from xkcd.com/1621/
# Unregistered from xkcd.com/48/
# Unregistered from xkcd.com/1620/
# Unregistered from xkcd.com/49/
# Unregistered from xkcd.com/1619/
# Unregistered from xkcd.com/50/
# Unregistered from xkcd.com/1618/
# Unregistered from xkcd.com/51/
# Unregistered from xkcd.com/1617/
# Unregistered from xkcd.com/52/
# Unregistered from xkcd.com/1616/
# Unregistered from xkcd.com/53/
# Unregistered from xkcd.com/54/
# Unregistered from xkcd.com/1615/
# Unregistered from xkcd.com/55/
# Unregistered from xkcd.com/1614/
# Unregistered from xkcd.com/56/
# Unregistered from xkcd.com/1613/
# Unregistered from xkcd.com/57/
# Unregistered from xkcd.com/1612/
# Unregistered from xkcd.com/1611/
# Unregistered from xkcd.com/58/
# Unregistered from xkcd.com/59/
# Unregistered from xkcd.com/1610/
# Unregistered from xkcd.com/60/
# Unregistered from xkcd.com/1609/
# Unregistered from xkcd.com/61/
# Unregistered from xkcd.com/1608/
# Unregistered from xkcd.com/62/
# Unregistered from xkcd.com/1607/
# Unregistered from xkcd.com/63/
# Unregistered from xkcd.com/1606/
# Unregistered from xkcd.com/64/
# Unregistered from xkcd.com/1605/
# Unregistered from xkcd.com/65/
# Unregistered from xkcd.com/1604/
# Unregistered from xkcd.com/66/
# Unregistered from xkcd.com/67/
# Unregistered from xkcd.com/1603/
# Unregistered from xkcd.com/68/
# Unregistered from xkcd.com/1602/
# Unregistered from xkcd.com/69/
# Unregistered from xkcd.com/1601/
# Unregistered from xkcd.com/70/
# Unregistered from xkcd.com/1600/
# Unregistered from xkcd.com/71/
# Unregistered from xkcd.com/1599/
# Unregistered from xkcd.com/72/
# Unregistered from xkcd.com/1598/
# Unregistered from xkcd.com/73/
# Unregistered from xkcd.com/74/
# Unregistered from xkcd.com/1597/
# Unregistered from xkcd.com/75/
# Unregistered from xkcd.com/1596/
# Unregistered from xkcd.com/1595/
# Unregistered from xkcd.com/76/
# Unregistered from xkcd.com/1594/
# Unregistered from xkcd.com/77/
# Unregistered from xkcd.com/1593/
# Unregistered from xkcd.com/78/
# Unregistered from xkcd.com/1592/
# Unregistered from xkcd.com/79/
# Unregistered from xkcd.com/1591/
# Unregistered from xkcd.com/1590/
# Unregistered from xkcd.com/80/
# Unregistered from xkcd.com/1589/
# Unregistered from xkcd.com/81/
# Unregistered from xkcd.com/1588/
# Unregistered from xkcd.com/82/
# Unregistered from xkcd.com/1587/
# Unregistered from xkcd.com/83/
# Unregistered from xkcd.com/1586/
# Unregistered from xkcd.com/84/
# Unregistered from xkcd.com/1585/
# Unregistered from xkcd.com/85/
# Unregistered from xkcd.com/1584/
# Unregistered from xkcd.com/86/
# Unregistered from xkcd.com/1583/
# Unregistered from xkcd.com/87/
# Unregistered from xkcd.com/1582/
# Unregistered from xkcd.com/88/
# Unregistered from xkcd.com/1581/
# Unregistered from xkcd.com/89/
# Unregistered from xkcd.com/1580/
# Unregistered from xkcd.com/90/
# Unregistered from xkcd.com/1579/
# Unregistered from xkcd.com/91/
# Unregistered from xkcd.com/1578/
# Unregistered from xkcd.com/92/
# Unregistered from xkcd.com/1577/
# Unregistered from xkcd.com/93/
# Unregistered from xkcd.com/1576/
# Unregistered from xkcd.com/94/
# Unregistered from xkcd.com/1575/
# Unregistered from xkcd.com/95/
# Unregistered from xkcd.com/1574/
# Unregistered from xkcd.com/96/
# Unregistered from xkcd.com/1573/
# Unregistered from xkcd.com/1572/
# Unregistered from xkcd.com/97/
# Unregistered from xkcd.com/1571/
# Unregistered from xkcd.com/98/
# Unregistered from xkcd.com/1570/
# Unregistered from xkcd.com/99/
# Unregistered from xkcd.com/1569/
# Unregistered from xkcd.com/100/
# Unregistered from xkcd.com/1568/
# Unregistered from xkcd.com/101/
# Unregistered from xkcd.com/102/
# Unregistered from xkcd.com/1567/
# Unregistered from xkcd.com/103/
# Unregistered from xkcd.com/1566/
# Unregistered from xkcd.com/104/
# Unregistered from xkcd.com/1565/
# Unregistered from xkcd.com/1564/
# Unregistered from xkcd.com/105/
# Unregistered from xkcd.com/1563/
# Unregistered from xkcd.com/106/
# Unregistered from xkcd.com/1562/
# Unregistered from xkcd.com/107/
# Unregistered from xkcd.com/1561/
# Unregistered from xkcd.com/108/
# Unregistered from xkcd.com/1560/
# Unregistered from xkcd.com/109/
# Unregistered from xkcd.com/110/
# Unregistered from xkcd.com/1559/
# Unregistered from xkcd.com/111/
# Unregistered from xkcd.com/1558/
# Unregistered from xkcd.com/112/
# Unregistered from xkcd.com/1557/
# Unregistered from xkcd.com/113/
# Unregistered from xkcd.com/1556/
# Unregistered from xkcd.com/114/
# Unregistered from xkcd.com/1555/
# Unregistered from xkcd.com/115/
# Unregistered from xkcd.com/1554/
# Unregistered from xkcd.com/116/
# Unregistered from xkcd.com/1553/
# Unregistered from xkcd.com/117/
# Unregistered from xkcd.com/1552/
# Unregistered from xkcd.com/118/
# Unregistered from xkcd.com/1551/
# Unregistered from xkcd.com/1550/
# Unregistered from xkcd.com/119/
# Unregistered from xkcd.com/1549/
# Unregistered from xkcd.com/120/
# Unregistered from xkcd.com/121/
# Unregistered from xkcd.com/1548/
# Unregistered from xkcd.com/122/
# Unregistered from xkcd.com/1547/
# Unregistered from xkcd.com/123/
# Unregistered from xkcd.com/1546/
# Unregistered from xkcd.com/124/
# Unregistered from xkcd.com/1545/
# Unregistered from xkcd.com/125/
# Unregistered from xkcd.com/1544/
# Unregistered from xkcd.com/126/
# Unregistered from xkcd.com/1543/
# Unregistered from xkcd.com/127/
# Unregistered from xkcd.com/1542/
# Unregistered from xkcd.com/128/
# Unregistered from xkcd.com/1541/
# Unregistered from xkcd.com/129/
# Unregistered from xkcd.com/1540/
# Unregistered from xkcd.com/130/
# Unregistered from xkcd.com/1539/
# Unregistered from xkcd.com/131/
# Unregistered from xkcd.com/1538/
# Unregistered from xkcd.com/132/
# Unregistered from xkcd.com/1537/
# Unregistered from xkcd.com/133/
# Unregistered from xkcd.com/1536/
# Unregistered from xkcd.com/134/
# Unregistered from xkcd.com/1535/
# Unregistered from xkcd.com/135/
# Unregistered from xkcd.com/1534/
# Unregistered from xkcd.com/1533/
# Unregistered from xkcd.com/136/
# Unregistered from xkcd.com/1532/
# Unregistered from xkcd.com/137/
# Unregistered from xkcd.com/1531/
# Unregistered from xkcd.com/138/
# Unregistered from xkcd.com/139/
# Unregistered from xkcd.com/1530/
# Unregistered from xkcd.com/140/
# Unregistered from xkcd.com/1529/
# Unregistered from xkcd.com/141/
# Unregistered from xkcd.com/1528/
# Unregistered from xkcd.com/142/
# Unregistered from xkcd.com/1527/
# Unregistered from xkcd.com/143/
# Unregistered from xkcd.com/1526/
# Unregistered from xkcd.com/144/
# Unregistered from xkcd.com/1525/
# Unregistered from xkcd.com/145/
# Unregistered from xkcd.com/1524/
# Unregistered from xkcd.com/146/
# Unregistered from xkcd.com/1523/
# Unregistered from xkcd.com/147/
# Unregistered from xkcd.com/1522/
# Unregistered from xkcd.com/148/
# Unregistered from xkcd.com/1521/
# Unregistered from xkcd.com/1520/
# Unregistered from xkcd.com/149/
# Unregistered from xkcd.com/1519/
# Unregistered from xkcd.com/150/
# Unregistered from xkcd.com/1518/
# Unregistered from xkcd.com/151/
# Unregistered from xkcd.com/1517/
# Unregistered from xkcd.com/152/
# Unregistered from xkcd.com/1516/
# Unregistered from xkcd.com/153/
# Unregistered from xkcd.com/1515/
# Unregistered from xkcd.com/154/
# Unregistered from xkcd.com/1514/
# Unregistered from xkcd.com/155/
# Unregistered from xkcd.com/1513/
# Unregistered from xkcd.com/156/
# Unregistered from xkcd.com/1512/
# Unregistered from xkcd.com/157/
# Unregistered from xkcd.com/1511/
# Unregistered from xkcd.com/158/
# Unregistered from xkcd.com/1510/
# Unregistered from xkcd.com/159/
# Unregistered from xkcd.com/1509/
# Unregistered from xkcd.com/160/
# Unregistered from xkcd.com/161/
# Unregistered from xkcd.com/1508/
# Unregistered from xkcd.com/162/
# Unregistered from xkcd.com/1507/
# Unregistered from xkcd.com/163/
# Unregistered from xkcd.com/1506/
# Unregistered from xkcd.com/164/
# Unregistered from xkcd.com//xkcd.com/1506/
# Unregistered from xkcd.com/1505/
# Unregistered from xkcd.com/1504/
# Unregistered from xkcd.com/165/
# Unregistered from xkcd.com/1503/
# Unregistered from xkcd.com/166/
# Unregistered from xkcd.com/1502/
# Unregistered from xkcd.com/167/
# Unregistered from xkcd.com/1501/
# Unregistered from xkcd.com/168/
# Unregistered from xkcd.com/169/
# Unregistered from xkcd.com/1500/
# Unregistered from xkcd.com/170/
# Unregistered from xkcd.com/1499/
# Unregistered from xkcd.com/171/
# Unregistered from xkcd.com/1498/
# Unregistered from xkcd.com/172/
# Unregistered from xkcd.com/1497/
# Unregistered from xkcd.com/173/
# Unregistered from xkcd.com/1496/
# Unregistered from xkcd.com/174/
# Unregistered from xkcd.com/1495/
# Unregistered from xkcd.com/175/
# Unregistered from xkcd.com/1494/
# Unregistered from xkcd.com/176/
# Unregistered from xkcd.com/1493/
# Unregistered from xkcd.com/177/
# Unregistered from xkcd.com/1492/
# Unregistered from xkcd.com/178/
# Unregistered from xkcd.com/1491/
# Unregistered from xkcd.com/179/
# Unregistered from xkcd.com/1490/
# Unregistered from xkcd.com/180/
# Unregistered from xkcd.com/1489/
# Unregistered from xkcd.com/181/
# Unregistered from xkcd.com/1488/
# Unregistered from xkcd.com/182/
# Unregistered from xkcd.com/1487/
# Unregistered from xkcd.com/183/
# Unregistered from xkcd.com/1486/
# Unregistered from xkcd.com/184/
# Unregistered from xkcd.com/1485/
# Unregistered from xkcd.com/185/
# Unregistered from xkcd.com/1484/
# Unregistered from xkcd.com/186/
# Unregistered from xkcd.com/1483/
# Unregistered from xkcd.com/187/
# Unregistered from xkcd.com/1482/
# Unregistered from xkcd.com/188/
# Unregistered from xkcd.com/1481/
# Unregistered from xkcd.com/189/
# Unregistered from xkcd.com/1480/
# Unregistered from xkcd.com/190/
# Unregistered from xkcd.com/1479/
# Unregistered from xkcd.com/191/
# Unregistered from xkcd.com/1478/
# Unregistered from xkcd.com/192/
# Unregistered from xkcd.com/1477/
# Unregistered from xkcd.com/193/
# Unregistered from xkcd.com/1476/
# Unregistered from xkcd.com/194/
# Unregistered from xkcd.com/1475/
# Unregistered from xkcd.com/195/
# Unregistered from xkcd.com/1474/
# Unregistered from xkcd.com/196/
# Unregistered from xkcd.com/1473/
# Unregistered from xkcd.com/1472/
# Unregistered from xkcd.com/197/
# Unregistered from xkcd.com/1471/
# Unregistered from xkcd.com/198/
# Unregistered from xkcd.com/1470/
# Unregistered from xkcd.com/199/
# Unregistered from xkcd.com/200/
# Unregistered from xkcd.com/1469/
# Unregistered from xkcd.com/1468/
# Unregistered from xkcd.com/201/
# Unregistered from xkcd.com/202/
# Unregistered from xkcd.com/1467/
# Unregistered from xkcd.com/1466/
# Unregistered from xkcd.com/203/
# Unregistered from xkcd.com/1465/
# Unregistered from xkcd.com/204/
# Unregistered from xkcd.com/1464/
# Unregistered from xkcd.com/205/
# Unregistered from xkcd.com/1463/
# Unregistered from xkcd.com/206/
# Unregistered from xkcd.com/1462/
# Unregistered from xkcd.com/207/
# Unregistered from xkcd.com/208/
# Unregistered from xkcd.com/1461/
# Unregistered from xkcd.com/209/
# Unregistered from xkcd.com/1460/
# Unregistered from xkcd.com/210/
# Unregistered from xkcd.com/1459/
# Unregistered from xkcd.com/211/
# Unregistered from xkcd.com/1458/
# Unregistered from xkcd.com/1457/
# Unregistered from xkcd.com/212/
# Unregistered from xkcd.com/1456/
# Unregistered from xkcd.com/213/
# Unregistered from xkcd.com/1455/
# Unregistered from xkcd.com/214/
# Unregistered from xkcd.com/1454/
# Unregistered from xkcd.com/215/
# Unregistered from xkcd.com/216/
# Unregistered from xkcd.com/1453/
# Unregistered from xkcd.com/217/
# Unregistered from xkcd.com/1452/
# Unregistered from xkcd.com/218/
# Unregistered from xkcd.com/1451/
# Unregistered from xkcd.com/219/
# Unregistered from xkcd.com/1450/
# Unregistered from xkcd.com/220/
# Unregistered from xkcd.com/1449/
# Unregistered from xkcd.com/221/
# Unregistered from xkcd.com/1448/
# Unregistered from xkcd.com/222/
# Unregistered from xkcd.com/1447/
# Unregistered from xkcd.com/223/
# Unregistered from xkcd.com/1446/
# Unregistered from xkcd.com/1445/
# Unregistered from xkcd.com/224/
# Unregistered from xkcd.com/1444/
# Unregistered from xkcd.com/225/
# Unregistered from xkcd.com/1443/
# Unregistered from xkcd.com/226/
# Unregistered from xkcd.com/1442/
# Unregistered from xkcd.com/227/
# Unregistered from xkcd.com/1441/
# Unregistered from xkcd.com/228/
# Unregistered from xkcd.com/1440/
# Unregistered from xkcd.com/229/
# Unregistered from xkcd.com/1439/
# Unregistered from xkcd.com/230/
# Unregistered from xkcd.com/1438/
# Unregistered from xkcd.com/231/
# Unregistered from xkcd.com/232/
# Unregistered from xkcd.com/1437/
# Unregistered from xkcd.com/233/
# Unregistered from xkcd.com/1436/
# Unregistered from xkcd.com/234/
# Unregistered from xkcd.com/1435/
# Unregistered from xkcd.com/235/
# Unregistered from xkcd.com/1434/
# Unregistered from xkcd.com/1433/
# Unregistered from xkcd.com/236/
# Unregistered from xkcd.com/1432/
# Unregistered from xkcd.com/237/
# Unregistered from xkcd.com/1431/
# Unregistered from xkcd.com/238/
# Unregistered from xkcd.com/1430/
# Unregistered from xkcd.com/239/
# Unregistered from xkcd.com/240/
# Unregistered from xkcd.com/1429/
# Unregistered from xkcd.com/1428/
# Unregistered from xkcd.com/241/
# Unregistered from xkcd.com/1427/
# Unregistered from xkcd.com/242/
# Unregistered from xkcd.com/1426/
# Unregistered from xkcd.com/243/
# Unregistered from xkcd.com/1425/
# Unregistered from xkcd.com/244/
# Unregistered from xkcd.com/1424/
# Unregistered from xkcd.com/245/
# Unregistered from xkcd.com/1423/
# Unregistered from xkcd.com/246/
# Unregistered from xkcd.com/1422/
# Unregistered from xkcd.com/247/
# Unregistered from xkcd.com/248/
# Unregistered from xkcd.com/1421/
# Unregistered from xkcd.com/249/
# Unregistered from xkcd.com/1420/
# Unregistered from xkcd.com/250/
# Unregistered from xkcd.com/1419/
# Unregistered from xkcd.com/251/
# Unregistered from xkcd.com/1418/
# Unregistered from xkcd.com/252/
# Unregistered from xkcd.com/1417/
# Unregistered from xkcd.com/253/
# Unregistered from xkcd.com/1416/
# Unregistered from xkcd.com/254/
# Unregistered from xkcd.com/1415/
# Unregistered from xkcd.com/255/
# Unregistered from xkcd.com/1414/
# Unregistered from xkcd.com/256/
# Unregistered from xkcd.com/1413/
# Unregistered from xkcd.com/257/
# Unregistered from xkcd.com/1412/
# Unregistered from xkcd.com/1411/
# Unregistered from xkcd.com/258/
# Unregistered from xkcd.com/1410/
# Unregistered from xkcd.com/259/
# Unregistered from xkcd.com/1409/
# Unregistered from xkcd.com/260/
# Unregistered from xkcd.com/1408/
# Unregistered from xkcd.com/261/
# Unregistered from xkcd.com/1407/
# Unregistered from xkcd.com/262/
# Unregistered from xkcd.com/1406/
# Unregistered from xkcd.com/263/
# Unregistered from xkcd.com/264/
# Unregistered from xkcd.com/1405/
# Unregistered from xkcd.com/265/
# Unregistered from xkcd.com/1404/
# Unregistered from xkcd.com/1403/
# Unregistered from xkcd.com/266/
# Unregistered from xkcd.com/1402/
# Unregistered from xkcd.com/267/
# Unregistered from xkcd.com/1401/
# Unregistered from xkcd.com/268/
# Unregistered from xkcd.com/1400/
# Unregistered from xkcd.com/269/
# Unregistered from xkcd.com/1399/
# Unregistered from xkcd.com/270/
# Unregistered from xkcd.com/1398/
# Unregistered from xkcd.com/271/
# Unregistered from xkcd.com/1397/
# Unregistered from xkcd.com/272/
# Unregistered from xkcd.com/1396/
# Unregistered from xkcd.com/273/
# Unregistered from xkcd.com/1395/
# Unregistered from xkcd.com/274/
# Unregistered from xkcd.com/275/
# Unregistered from xkcd.com/1394/
# Unregistered from xkcd.com/276/
# Unregistered from xkcd.com/1393/
# Unregistered from xkcd.com/277/
# Unregistered from xkcd.com/1392/
# Unregistered from xkcd.com/278/
# Unregistered from xkcd.com/1391/
# Unregistered from xkcd.com/279/
# Unregistered from xkcd.com/1390/
# Unregistered from xkcd.com/280/
# Unregistered from xkcd.com/1389/
# Unregistered from xkcd.com/281/
# Unregistered from xkcd.com/1388/
# Unregistered from xkcd.com/282/
# Unregistered from xkcd.com/1387/
# Unregistered from xkcd.com/283/
# Unregistered from xkcd.com/1386/
# Unregistered from xkcd.com/284/
# Unregistered from xkcd.com/285/
# Unregistered from xkcd.com/1385/
# Unregistered from xkcd.com/286/
# Unregistered from xkcd.com/1384/
# Unregistered from xkcd.com/287/
# Unregistered from xkcd.com/1383/
# Unregistered from xkcd.com/288/
# Unregistered from xkcd.com/1382/
# Unregistered from xkcd.com/1381/
# Unregistered from xkcd.com/289/
# Unregistered from xkcd.com/1380/
# Unregistered from xkcd.com/290/
# Unregistered from xkcd.com/1379/
# Unregistered from xkcd.com/291/
# Unregistered from xkcd.com/1378/
# Unregistered from xkcd.com/292/
# Unregistered from xkcd.com/1377/
# Unregistered from xkcd.com/293/
# Unregistered from xkcd.com/1376/
# Unregistered from xkcd.com/294/
# Unregistered from xkcd.com/1375/
# Unregistered from xkcd.com/295/
# Unregistered from xkcd.com/1374/
# Unregistered from xkcd.com/296/
# Unregistered from xkcd.com/1373/
# Unregistered from xkcd.com/297/
# Unregistered from xkcd.com/1372/
# Unregistered from xkcd.com/298/
# Unregistered from xkcd.com/1371/
# Unregistered from xkcd.com/299/
# Unregistered from xkcd.com/1370/
# Unregistered from xkcd.com/300/
# Unregistered from xkcd.com/1369/
# Unregistered from xkcd.com/301/
# Unregistered from xkcd.com/1368/
# Unregistered from xkcd.com/302/
# Unregistered from xkcd.com/1367/
# Unregistered from xkcd.com/303/
# Unregistered from xkcd.com/1366/
# Unregistered from xkcd.com/304/
# Unregistered from xkcd.com/1365/
# Unregistered from xkcd.com/305/
# Unregistered from xkcd.com/1364/
# Unregistered from xkcd.com/306/
# Unregistered from xkcd.com/1363/
# Unregistered from xkcd.com/307/
# Unregistered from xkcd.com/1362/
# Unregistered from xkcd.com/308/
# Unregistered from xkcd.com/1361/
# Unregistered from xkcd.com/309/
# Unregistered from xkcd.com/1360/
# Unregistered from xkcd.com/310/
# Unregistered from xkcd.com/1359/
# Unregistered from xkcd.com/311/
# Unregistered from xkcd.com/1358/
# Unregistered from xkcd.com/312/
# Unregistered from xkcd.com/1357/
# Unregistered from xkcd.com/313/
# Unregistered from xkcd.com/1356/
# Unregistered from xkcd.com/1355/
# Unregistered from xkcd.com/314/
# Unregistered from xkcd.com/1354/
# Unregistered from xkcd.com/315/
# Unregistered from xkcd.com/1353/
# Unregistered from xkcd.com/316/
# Unregistered from xkcd.com/1352/
# Unregistered from xkcd.com/317/
# Unregistered from xkcd.com/1351/
# Unregistered from xkcd.com/318/
# Unregistered from xkcd.com/319/
# Unregistered from xkcd.com/1350/
# Unregistered from xkcd.com/320/
# Unregistered from xkcd.com/1349/
# Unregistered from xkcd.com/321/
# Unregistered from xkcd.com/1348/
# Unregistered from xkcd.com/322/
# Unregistered from xkcd.com/1347/
# Unregistered from xkcd.com/323/
# Unregistered from xkcd.com/1346/
# Unregistered from xkcd.com/324/
# Unregistered from xkcd.com/1345/
# Unregistered from xkcd.com/325/
# Unregistered from xkcd.com/1344/
# Unregistered from xkcd.com/326/
# Unregistered from xkcd.com/1343/
# Unregistered from xkcd.com/327/
# Unregistered from xkcd.com/1342/
# Unregistered from xkcd.com/328/
# Unregistered from xkcd.com/1341/
# Unregistered from xkcd.com/329/
# Unregistered from xkcd.com/1340/
# Unregistered from xkcd.com/330/
# Unregistered from xkcd.com/1339/
# Unregistered from xkcd.com/331/
# Unregistered from xkcd.com/1338/
# Unregistered from xkcd.com/332/
# Unregistered from xkcd.com/1337/
# Unregistered from xkcd.com/1336/
# Unregistered from xkcd.com/333/
# Unregistered from xkcd.com/1335/
# Unregistered from xkcd.com/334/
# Unregistered from xkcd.com/1334/
# Unregistered from xkcd.com/335/
# Unregistered from xkcd.com/1333/
# Unregistered from xkcd.com/336/
# Unregistered from xkcd.com/1332/
# Unregistered from xkcd.com/337/
# Unregistered from xkcd.com/1331/
# Unregistered from xkcd.com/338/
# Unregistered from xkcd.com/1330/
# Unregistered from xkcd.com/339/
# Unregistered from xkcd.com/1329/
# Unregistered from xkcd.com/340/
# Unregistered from xkcd.com/1328/
# Unregistered from xkcd.com/341/
# Unregistered from xkcd.com/1327/
# Unregistered from xkcd.com/342/
# Unregistered from xkcd.com/1326/
# Unregistered from xkcd.com/343/
# Unregistered from xkcd.com/1325/
# Unregistered from xkcd.com/344/
# Unregistered from xkcd.com/1324/
# Unregistered from xkcd.com/345/
# Unregistered from xkcd.com/1323/
# Unregistered from xkcd.com/346/
# Unregistered from xkcd.com/1322/
# Unregistered from xkcd.com/347/
# Unregistered from xkcd.com/1321/
# Unregistered from xkcd.com/348/
# Unregistered from xkcd.com/1320/
# Unregistered from xkcd.com/349/
# Unregistered from xkcd.com/1319/
# Unregistered from xkcd.com/350/
# Unregistered from xkcd.com/1318/
# Unregistered from xkcd.com/351/
# Unregistered from xkcd.com/1317/
# Unregistered from xkcd.com/352/
# Unregistered from xkcd.com/1316/
# Unregistered from xkcd.com/353/
# Unregistered from xkcd.com/1315/
# Unregistered from xkcd.com/354/
# Unregistered from xkcd.com/1314/
# Unregistered from xkcd.com/355/
# Unregistered from xkcd.com/1313/
# Unregistered from xkcd.com/356/
# Unregistered from xkcd.com/1312/
# Unregistered from xkcd.com/357/
# Unregistered from xkcd.com/1311/
# Unregistered from xkcd.com/358/
# Unregistered from xkcd.com/1310/
# Unregistered from xkcd.com/359/
# Unregistered from xkcd.com/1309/
# Unregistered from xkcd.com/360/
# Unregistered from xkcd.com/1308/
# Unregistered from xkcd.com/361/
# Unregistered from xkcd.com/1307/
# Unregistered from xkcd.com/362/
# Unregistered from xkcd.com/1306/
# Unregistered from xkcd.com/363/
# Unregistered from xkcd.com/1305/
# Unregistered from xkcd.com/364/
# Unregistered from xkcd.com/1304/
# Unregistered from xkcd.com/365/
# Unregistered from xkcd.com/1303/
# Unregistered from xkcd.com/366/
# Unregistered from xkcd.com/1302/
# Unregistered from xkcd.com/367/
# Unregistered from xkcd.com/1301/
# Unregistered from xkcd.com/368/
# Unregistered from xkcd.com/369/
# Unregistered from xkcd.com/1300/
# Unregistered from xkcd.com/370/
# Unregistered from xkcd.com/1299/
# Unregistered from xkcd.com/371/
# Unregistered from xkcd.com/1298/
# Unregistered from xkcd.com/372/
# Unregistered from xkcd.com/1297/
# Unregistered from xkcd.com/373/
# Unregistered from xkcd.com/1296/
# Unregistered from xkcd.com/374/
# Unregistered from xkcd.com/1295/
# Unregistered from xkcd.com/375/
# Unregistered from xkcd.com/1294/
# Unregistered from xkcd.com/376/
# Unregistered from xkcd.com/1293/
# Unregistered from xkcd.com/377/
# Unregistered from xkcd.com/1292/
# Unregistered from xkcd.com/378/
# Unregistered from xkcd.com/1291/
# Unregistered from xkcd.com/1290/
# Unregistered from xkcd.com/379/
# Unregistered from xkcd.com/380/
# Unregistered from xkcd.com/1289/
# Unregistered from xkcd.com/1288/
# Unregistered from xkcd.com/381/
# Unregistered from xkcd.com/1287/
# Unregistered from xkcd.com/382/
# Unregistered from xkcd.com/1286/
# Unregistered from xkcd.com/383/
# Unregistered from xkcd.com/1285/
# Unregistered from xkcd.com/384/
# Unregistered from xkcd.com/385/
# Unregistered from xkcd.com/1284/
# Unregistered from xkcd.com/1283/
# Unregistered from xkcd.com/386/
# Unregistered from xkcd.com/1282/
# Unregistered from xkcd.com/387/
# Unregistered from xkcd.com/388/
# Unregistered from xkcd.com/1281/
# Unregistered from xkcd.com/1280/
# Unregistered from xkcd.com/389/
# Unregistered from xkcd.com/1279/
# Unregistered from xkcd.com/390/
# Unregistered from xkcd.com/391/
# Unregistered from xkcd.com/1278/
# Unregistered from xkcd.com/392/
# Unregistered from xkcd.com/1277/
# Unregistered from xkcd.com/1276/
# Unregistered from xkcd.com/393/
# Unregistered from xkcd.com/394/
# Unregistered from xkcd.com/1275/
# Unregistered from xkcd.com/395/
# Unregistered from xkcd.com/1274/
# Unregistered from xkcd.com/396/
# Unregistered from xkcd.com/1273/
# Unregistered from xkcd.com/1272/
# Unregistered from xkcd.com/397/
# Unregistered from xkcd.com/1271/
# Unregistered from xkcd.com/398/
# Unregistered from xkcd.com/1270/
# Unregistered from xkcd.com/399/
# Unregistered from xkcd.com/1269/
# Unregistered from xkcd.com/400/
# Unregistered from xkcd.com/1268/
# Unregistered from xkcd.com/401/
# Unregistered from xkcd.com/1267/
# Unregistered from xkcd.com/402/
# Unregistered from xkcd.com/1266/
# Unregistered from xkcd.com/403/
# Unregistered from xkcd.com/1265/
# Unregistered from xkcd.com/1264/
# Unregistered from xkcd.com/405/
# Unregistered from xkcd.com/1263/
# Unregistered from xkcd.com/406/
# Unregistered from xkcd.com/1262/
# Unregistered from xkcd.com/407/
# Unregistered from xkcd.com/1261/
# Unregistered from xkcd.com/408/
# Unregistered from xkcd.com/1260/
# Unregistered from xkcd.com/409/
# Unregistered from xkcd.com/1259/
# Unregistered from xkcd.com/410/
# Unregistered from xkcd.com/1258/
# Unregistered from xkcd.com/411/
# Unregistered from xkcd.com/1257/
# Unregistered from xkcd.com/412/
# Unregistered from xkcd.com/1256/
# Unregistered from xkcd.com/413/
# Unregistered from xkcd.com/1255/
# Unregistered from xkcd.com/414/
# Unregistered from xkcd.com/1254/
# Unregistered from xkcd.com/415/
# Unregistered from xkcd.com/1253/
# Unregistered from xkcd.com/416/
# Unregistered from xkcd.com/1252/
# Unregistered from xkcd.com/417/
# Unregistered from xkcd.com/1251/
# Unregistered from xkcd.com/418/
# Unregistered from xkcd.com/1250/
# Unregistered from xkcd.com/419/
# Unregistered from xkcd.com/1249/
# Unregistered from xkcd.com/420/
# Unregistered from xkcd.com/1248/
# Unregistered from xkcd.com/421/
# Unregistered from xkcd.com/1247/
# Unregistered from xkcd.com/422/
# Unregistered from xkcd.com/1246/
# Unregistered from xkcd.com/423/
# Unregistered from xkcd.com/1245/
# Unregistered from xkcd.com/424/
# Unregistered from xkcd.com/1244/
# Unregistered from xkcd.com/425/
# Unregistered from xkcd.com/1243/
# Unregistered from xkcd.com/426/
# Unregistered from xkcd.com/1242/
# Unregistered from xkcd.com/1241/
# Unregistered from xkcd.com/427/
# Unregistered from xkcd.com/1240/
# Unregistered from xkcd.com/428/
# Unregistered from xkcd.com/1239/
# Unregistered from xkcd.com/429/
# Unregistered from xkcd.com/1238/
# Unregistered from xkcd.com/430/
# Unregistered from xkcd.com/431/
# Unregistered from xkcd.com/1237/
# Unregistered from xkcd.com/432/
# Unregistered from xkcd.com/1236/
# Unregistered from xkcd.com/433/
# Unregistered from xkcd.com/1235/
# Unregistered from xkcd.com/434/
# Unregistered from xkcd.com/1234/
# Unregistered from xkcd.com/435/
# Unregistered from xkcd.com/1233/
# Unregistered from xkcd.com/436/
# Unregistered from xkcd.com/1232/
# Unregistered from xkcd.com/437/
# Unregistered from xkcd.com/1231/
# Unregistered from xkcd.com/438/
# Unregistered from xkcd.com/1230/
# Unregistered from xkcd.com/439/
# Unregistered from xkcd.com/1229/
# Unregistered from xkcd.com/440/
# Unregistered from xkcd.com/1228/
# Unregistered from xkcd.com/441/
# Unregistered from xkcd.com/442/
# Unregistered from xkcd.com/1227/
# Unregistered from xkcd.com/443/
# Unregistered from xkcd.com/1226/
# Unregistered from xkcd.com/444/
# Unregistered from xkcd.com/1225/
# Unregistered from xkcd.com/1224/
# Unregistered from xkcd.com/445/
# Unregistered from xkcd.com/1223/
# Unregistered from xkcd.com/446/
# Unregistered from xkcd.com/1222/
# Unregistered from xkcd.com/447/
# Unregistered from xkcd.com/1221/
# Unregistered from xkcd.com/448/
# Unregistered from xkcd.com/1220/
# Unregistered from xkcd.com/449/
# Unregistered from xkcd.com/1219/
# Unregistered from xkcd.com/450/
# Unregistered from xkcd.com/1218/
# Unregistered from xkcd.com/451/
# Unregistered from xkcd.com/1217/
# Unregistered from xkcd.com/452/
# Unregistered from xkcd.com/1216/
# Unregistered from xkcd.com/453/
# Unregistered from xkcd.com/454/
# Unregistered from xkcd.com/1215/
# Unregistered from xkcd.com/455/
# Unregistered from xkcd.com/1214/
# Unregistered from xkcd.com/1213/
# Unregistered from xkcd.com/456/
# Unregistered from xkcd.com/1212/
# Unregistered from xkcd.com/457/
# Unregistered from xkcd.com/1211/
# Unregistered from xkcd.com/458/
# Unregistered from xkcd.com/1210/
# Unregistered from xkcd.com/459/
# Unregistered from xkcd.com/1209/
# Unregistered from xkcd.com/460/
# Unregistered from xkcd.com/1208/
# Unregistered from xkcd.com/461/
# Unregistered from xkcd.com/1207/
# Unregistered from xkcd.com/462/
# Unregistered from xkcd.com/1206/
# Unregistered from xkcd.com/463/
# Unregistered from xkcd.com/1205/
# Unregistered from xkcd.com/464/
# Unregistered from xkcd.com/1204/
# Unregistered from xkcd.com/465/
# Unregistered from xkcd.com/1203/
# Unregistered from xkcd.com/466/
# Unregistered from xkcd.com/1202/
# Unregistered from xkcd.com/467/
# Unregistered from xkcd.com/1201/
# Unregistered from xkcd.com/468/
# Unregistered from xkcd.com/1200/
# Unregistered from xkcd.com/469/
# Unregistered from xkcd.com/1199/
# Unregistered from xkcd.com/470/
# Unregistered from xkcd.com/1198/
# Unregistered from xkcd.com/471/
# Unregistered from xkcd.com/1197/
# Unregistered from xkcd.com/472/
# Unregistered from xkcd.com/1196/
# Unregistered from xkcd.com/473/
# Unregistered from xkcd.com/1195/
# Unregistered from xkcd.com/474/
# Unregistered from xkcd.com/475/
# Unregistered from xkcd.com/1194/
# Unregistered from xkcd.com/1193/
# Unregistered from xkcd.com/476/
# Unregistered from xkcd.com/1192/
# Unregistered from xkcd.com/477/
# Unregistered from xkcd.com/1191/
# Unregistered from xkcd.com/478/
# Unregistered from xkcd.com/1190/
# Unregistered from xkcd.com/479/
# Unregistered from xkcd.com/1189/
# Unregistered from xkcd.com/480/
# Unregistered from xkcd.com/1188/
# Unregistered from xkcd.com/481/
# Unregistered from xkcd.com/1187/
# Unregistered from xkcd.com/482/
# Unregistered from xkcd.com/1186/
# Unregistered from xkcd.com/483/
# Unregistered from xkcd.com/1185/
# Unregistered from xkcd.com/484/
# Unregistered from xkcd.com/1184/
# Unregistered from xkcd.com/485/
# Unregistered from xkcd.com/1183/
# Unregistered from xkcd.com/486/
# Unregistered from xkcd.com/1182/
# Unregistered from xkcd.com/487/
# Unregistered from xkcd.com/1181/
# Unregistered from xkcd.com/488/
# Unregistered from xkcd.com/1180/
# Unregistered from xkcd.com/489/
# Unregistered from xkcd.com/1179/
# Unregistered from xkcd.com/490/
# Unregistered from xkcd.com/1178/
# Unregistered from xkcd.com/491/
# Unregistered from xkcd.com/1177/
# Unregistered from xkcd.com/492/
# Unregistered from xkcd.com/1176/
# Unregistered from xkcd.com/493/
# Unregistered from xkcd.com/1175/
# Unregistered from xkcd.com/494/
# Unregistered from xkcd.com/1174/
# Unregistered from xkcd.com/495/
# Unregistered from xkcd.com/1173/
# Unregistered from xkcd.com/496/
# Unregistered from xkcd.com/1172/
# Unregistered from xkcd.com/497/
# Unregistered from xkcd.com/1171/
# Unregistered from xkcd.com/498/
# Unregistered from xkcd.com/1170/
# Unregistered from xkcd.com/499/
# Unregistered from xkcd.com/1169/
# Unregistered from xkcd.com/500/
# Unregistered from xkcd.com/1168/
# Unregistered from xkcd.com/501/
# Unregistered from xkcd.com/502/
# Unregistered from xkcd.com/1167/
# Unregistered from xkcd.com/503/
# Unregistered from xkcd.com/1166/
# Unregistered from xkcd.com/504/
# Unregistered from xkcd.com/1165/
# Unregistered from xkcd.com/505/
# Unregistered from xkcd.com/1164/
# Unregistered from xkcd.com/506/
# Unregistered from xkcd.com/1163/
# Unregistered from xkcd.com/507/
# Unregistered from xkcd.com/1162/
# Unregistered from xkcd.com/508/
# Unregistered from xkcd.com/1161/
# Unregistered from xkcd.com/1160/
# Unregistered from xkcd.com/509/
# Unregistered from xkcd.com/1159/
# Unregistered from xkcd.com/510/
# Unregistered from xkcd.com/1158/
# Unregistered from xkcd.com/511/
# Unregistered from xkcd.com/1157/
# Unregistered from xkcd.com/512/
# Unregistered from xkcd.com/513/
# Unregistered from xkcd.com/1156/
# Unregistered from xkcd.com/514/
# Unregistered from xkcd.com/1155/
# Unregistered from xkcd.com/515/
# Unregistered from xkcd.com/1154/
# Unregistered from xkcd.com/516/
# Unregistered from xkcd.com/1153/
# Unregistered from xkcd.com/517/
# Unregistered from xkcd.com/1152/
# Unregistered from xkcd.com/518/
# Unregistered from xkcd.com/1151/
# Unregistered from xkcd.com/519/
# Unregistered from xkcd.com/1150/
# Unregistered from xkcd.com/520/
# Unregistered from xkcd.com/1149/
# Unregistered from xkcd.com/1148/
# Unregistered from xkcd.com/521/
# Unregistered from xkcd.com/1147/
# Unregistered from xkcd.com/522/
# Unregistered from xkcd.com/1146/
# Unregistered from xkcd.com/523/
# Unregistered from xkcd.com/1145/
# Unregistered from xkcd.com/524/
# Unregistered from xkcd.com/1144/
# Unregistered from xkcd.com/525/
# Unregistered from xkcd.com/1143/
# Unregistered from xkcd.com/526/
# Unregistered from xkcd.com/1142/
# Unregistered from xkcd.com/527/
# Unregistered from xkcd.com/1141/
# Unregistered from xkcd.com/1140/
# Unregistered from xkcd.com/528/
# Unregistered from xkcd.com/529/
# Unregistered from xkcd.com/1139/
# Unregistered from xkcd.com/1138/
# Unregistered from xkcd.com/530/
# Unregistered from xkcd.com/531/
# Unregistered from xkcd.com/1137/
# Unregistered from xkcd.com/532/
# Unregistered from xkcd.com/1136/
# Unregistered from xkcd.com/1135/
# Unregistered from xkcd.com/533/
# Unregistered from xkcd.com/1134/
# Unregistered from xkcd.com/534/
# Unregistered from xkcd.com/1133/
# Unregistered from xkcd.com/535/
# Unregistered from xkcd.com/536/
# Unregistered from xkcd.com/1132/
# Unregistered from xkcd.com/537/
# Unregistered from xkcd.com/1131/
# Unregistered from xkcd.com/538/
# Unregistered from xkcd.com/1130/
# Unregistered from xkcd.com/539/
# Unregistered from xkcd.com/1129/
# Unregistered from xkcd.com/1128/
# Unregistered from xkcd.com/540/
# Unregistered from xkcd.com/541/
# Unregistered from xkcd.com/1127/
# Unregistered from xkcd.com/542/
# Unregistered from xkcd.com/1126/
# Unregistered from xkcd.com/543/
# Unregistered from xkcd.com/1125/
# Unregistered from xkcd.com/544/
# Unregistered from xkcd.com/1124/
# Unregistered from xkcd.com/545/
# Unregistered from xkcd.com/1123/
# Unregistered from xkcd.com/546/
# Unregistered from xkcd.com/1122/
# Unregistered from xkcd.com/547/
# Unregistered from xkcd.com/548/
# Unregistered from xkcd.com/1121/
# Unregistered from xkcd.com/549/
# Unregistered from xkcd.com/1120/
# Unregistered from xkcd.com/550/
# Unregistered from xkcd.com/1119/
# Unregistered from xkcd.com/1118/
# Unregistered from xkcd.com/551/
# Unregistered from xkcd.com/1117/
# Unregistered from xkcd.com/552/
# Unregistered from xkcd.com/1116/
# Unregistered from xkcd.com/553/
# Unregistered from xkcd.com/1115/
# Unregistered from xkcd.com/554/
# Unregistered from xkcd.com/1114/
# Unregistered from xkcd.com/555/
# Unregistered from xkcd.com/1113/
# Unregistered from xkcd.com/556/
# Unregistered from xkcd.com/1112/
# Unregistered from xkcd.com/557/
# Unregistered from xkcd.com/1111/
# Unregistered from xkcd.com/558/
# Unregistered from xkcd.com/1110/
# Unregistered from xkcd.com/559/
# Unregistered from xkcd.com/1109/
# Unregistered from xkcd.com/560/
# Unregistered from xkcd.com/1108/
# Unregistered from xkcd.com/561/
# Unregistered from xkcd.com/1107/
# Unregistered from xkcd.com/562/
# Unregistered from xkcd.com/1106/
# Unregistered from xkcd.com/563/
# Unregistered from xkcd.com/1105/
# Unregistered from xkcd.com/564/
# Unregistered from xkcd.com/1104/
# Unregistered from xkcd.com/565/
# Unregistered from xkcd.com/1103/
# Unregistered from xkcd.com/566/
# Unregistered from xkcd.com/1102/
# Unregistered from xkcd.com/567/
# Unregistered from xkcd.com/1101/
# Unregistered from xkcd.com/568/
# Unregistered from xkcd.com/1100/
# Unregistered from xkcd.com/569/
# Unregistered from xkcd.com/1099/
# Unregistered from xkcd.com/570/
# Unregistered from xkcd.com/1098/
# Unregistered from xkcd.com/571/
# Unregistered from xkcd.com/1097/
# Unregistered from xkcd.com/1096/
# Unregistered from xkcd.com/572/
# Unregistered from xkcd.com/1095/
# Unregistered from xkcd.com/573/
# Unregistered from xkcd.com/1094/
# Unregistered from xkcd.com/574/
# Unregistered from xkcd.com/575/
# Unregistered from xkcd.com/1093/
# Unregistered from xkcd.com/576/
# Unregistered from xkcd.com/1092/
# Unregistered from xkcd.com/577/
# Unregistered from xkcd.com/1091/
# Unregistered from xkcd.com/1090/
# Unregistered from xkcd.com/578/
# Unregistered from xkcd.com/1089/
# Unregistered from xkcd.com/579/
# Unregistered from xkcd.com/1088/
# Unregistered from xkcd.com/1087/
# Unregistered from xkcd.com/580/
# Unregistered from xkcd.com/581/
# Unregistered from xkcd.com/1086/
# Unregistered from xkcd.com/582/
# Unregistered from xkcd.com/1085/
# Unregistered from xkcd.com/583/
# Unregistered from xkcd.com/1084/
# Unregistered from xkcd.com/584/
# Unregistered from xkcd.com/1083/
# Unregistered from xkcd.com/585/
# Unregistered from xkcd.com/1082/
# Unregistered from xkcd.com/586/
# Unregistered from xkcd.com/1081/
# Unregistered from xkcd.com/587/
# Unregistered from xkcd.com/1080/
# Unregistered from xkcd.com/588/
# Unregistered from xkcd.com/1079/
# Unregistered from xkcd.com/589/
# Unregistered from xkcd.com/1078/
# Unregistered from xkcd.com/590/
# Unregistered from xkcd.com/1077/
# Unregistered from xkcd.com/591/
# Unregistered from xkcd.com/1076/
# Unregistered from xkcd.com/592/
# Unregistered from xkcd.com/1075/
# Unregistered from xkcd.com/593/
# Unregistered from xkcd.com/1074/
# Unregistered from xkcd.com/594/
# Unregistered from xkcd.com/1073/
# Unregistered from xkcd.com/595/
# Unregistered from xkcd.com/1072/
# Unregistered from xkcd.com/596/
# Unregistered from xkcd.com/1071/
# Unregistered from xkcd.com/597/
# Unregistered from xkcd.com/598/
# Unregistered from xkcd.com/1070/
# Unregistered from xkcd.com/599/
# Unregistered from xkcd.com/1069/
# Unregistered from xkcd.com/1068/
# Unregistered from xkcd.com/600/
# Unregistered from xkcd.com/1067/
# Unregistered from xkcd.com/601/
# Unregistered from xkcd.com/1066/
# Unregistered from xkcd.com/602/
# Unregistered from xkcd.com/1065/
# Unregistered from xkcd.com/603/
# Unregistered from xkcd.com/1064/
# Unregistered from xkcd.com/604/
# Unregistered from xkcd.com/1063/
# Unregistered from xkcd.com/605/
# Unregistered from xkcd.com/1062/
# Unregistered from xkcd.com/606/
# Unregistered from xkcd.com/1061/
# Unregistered from xkcd.com/607/
# Unregistered from xkcd.com/1060/
# Unregistered from xkcd.com/608/
# Unregistered from xkcd.com/1059/
# Unregistered from xkcd.com/609/
# Unregistered from xkcd.com/1058/
# Unregistered from xkcd.com/610/
# Unregistered from xkcd.com/1057/
# Unregistered from xkcd.com/611/
# Unregistered from xkcd.com/1056/
# Unregistered from xkcd.com/612/
# Unregistered from xkcd.com/1055/
# Unregistered from xkcd.com/613/
# Unregistered from xkcd.com/1054/
# Unregistered from xkcd.com/614/
# Unregistered from xkcd.com/1053/
# Unregistered from xkcd.com/615/
# Unregistered from xkcd.com/1052/
# Unregistered from xkcd.com/616/
# Unregistered from xkcd.com/1051/
# Unregistered from xkcd.com/617/
# Unregistered from xkcd.com/1050/
# Unregistered from xkcd.com/618/
# Unregistered from xkcd.com/1049/
# Unregistered from xkcd.com/619/
# Unregistered from xkcd.com/1048/
# Unregistered from xkcd.com/620/
# Unregistered from xkcd.com/1047/
# Unregistered from xkcd.com/621/
# Unregistered from xkcd.com/1046/
# Unregistered from xkcd.com/622/
# Unregistered from xkcd.com/623/
# Unregistered from xkcd.com/1045/
# Unregistered from xkcd.com/624/
# Unregistered from xkcd.com/1044/
# Unregistered from xkcd.com/625/
# Unregistered from xkcd.com/1043/
# Unregistered from xkcd.com/626/
# Unregistered from xkcd.com/1042/
# Unregistered from xkcd.com/627/
# Unregistered from xkcd.com/1041/
# Unregistered from xkcd.com/628/
# Unregistered from xkcd.com/1040/
# Unregistered from xkcd.com/629/
# Unregistered from xkcd.com/1039/
# Unregistered from xkcd.com/630/
# Unregistered from xkcd.com/1038/
# Unregistered from xkcd.com/631/
# Unregistered from xkcd.com/1037/
# Unregistered from xkcd.com/632/
# Unregistered from xkcd.com/1036/
# Unregistered from xkcd.com/633/
# Unregistered from xkcd.com/1035/
# Unregistered from xkcd.com/634/
# Unregistered from xkcd.com/1034/
# Unregistered from xkcd.com/635/
# Unregistered from xkcd.com/1033/
# Unregistered from xkcd.com/636/
# Unregistered from xkcd.com/1032/
# Unregistered from xkcd.com/637/
# Unregistered from xkcd.com/1031/
# Unregistered from xkcd.com/638/
# Unregistered from xkcd.com/1030/
# Unregistered from xkcd.com/639/
# Unregistered from xkcd.com/1029/
# Unregistered from xkcd.com/640/
# Unregistered from xkcd.com/1028/
# Unregistered from xkcd.com/641/
# Unregistered from xkcd.com/1027/
# Unregistered from xkcd.com/642/
# Unregistered from xkcd.com/1026/
# Unregistered from xkcd.com/643/
# Unregistered from xkcd.com/1025/
# Unregistered from xkcd.com/644/
# Unregistered from xkcd.com/1024/
# Unregistered from xkcd.com/645/
# Unregistered from xkcd.com/1023/
# Unregistered from xkcd.com/646/
# Unregistered from xkcd.com/647/
# Unregistered from xkcd.com/1022/
# Unregistered from xkcd.com/648/
# Unregistered from xkcd.com/1021/
# Unregistered from xkcd.com/649/
# Unregistered from xkcd.com/1020/
# Unregistered from xkcd.com/650/
# Unregistered from xkcd.com/1019/
# Unregistered from xkcd.com/651/
# Unregistered from xkcd.com/1018/
# Unregistered from xkcd.com/652/
# Unregistered from xkcd.com/1017/
# Unregistered from xkcd.com/653/
# Unregistered from xkcd.com/1016/
# Unregistered from xkcd.com/654/
# Unregistered from xkcd.com/1015/
# Unregistered from xkcd.com/655/
# Unregistered from xkcd.com/1014/
# Unregistered from xkcd.com/656/
# Unregistered from xkcd.com/1013/
# Unregistered from xkcd.com/657/
# Unregistered from xkcd.com/1012/
# Unregistered from xkcd.com/658/
# Unregistered from xkcd.com/1011/
# Unregistered from xkcd.com/659/
# Unregistered from xkcd.com/1010/
# Unregistered from xkcd.com/660/
# Unregistered from xkcd.com/1009/
# Unregistered from xkcd.com/661/
# Unregistered from xkcd.com/1008/
# Unregistered from xkcd.com/662/
# Unregistered from xkcd.com/1007/
# Unregistered from xkcd.com/663/
# Unregistered from xkcd.com/1006/
# Unregistered from xkcd.com/664/
# Unregistered from xkcd.com/1005/
# Unregistered from xkcd.com/1004/
# Unregistered from xkcd.com/665/
# Unregistered from xkcd.com/1003/
# Unregistered from xkcd.com/666/
# Unregistered from xkcd.com/1002/
# Unregistered from xkcd.com/667/
# Unregistered from xkcd.com/668/
# Unregistered from xkcd.com/1001/
# Unregistered from xkcd.com/1000/
# Unregistered from xkcd.com/669/
# Unregistered from xkcd.com/999/
# Unregistered from xkcd.com/670/
# Unregistered from xkcd.com/998/
# Unregistered from xkcd.com/671/
# Unregistered from xkcd.com/997/
# Unregistered from xkcd.com/672/
# Unregistered from xkcd.com/996/
# Unregistered from xkcd.com/673/
# Unregistered from xkcd.com/995/
# Unregistered from xkcd.com/674/
# Unregistered from xkcd.com/994/
# Unregistered from xkcd.com/675/
# Unregistered from xkcd.com/993/
# Unregistered from xkcd.com/676/
# Unregistered from xkcd.com/992/
# Unregistered from xkcd.com/677/
# Unregistered from xkcd.com/678/
# Unregistered from xkcd.com/991/
# Unregistered from xkcd.com/679/
# Unregistered from xkcd.com/990/
# Unregistered from xkcd.com/680/
# Unregistered from xkcd.com/989/
# Unregistered from xkcd.com/681/
# Unregistered from xkcd.com/988/
# Unregistered from xkcd.com/682/
# Unregistered from xkcd.com/987/
# Unregistered from xkcd.com/683/
# Unregistered from xkcd.com/986/
# Unregistered from xkcd.com/684/
# Unregistered from xkcd.com/985/
# Unregistered from xkcd.com/685/
# Unregistered from xkcd.com/984/
# Unregistered from xkcd.com/686/
# Unregistered from xkcd.com/983/
# Unregistered from xkcd.com/687/
# Unregistered from xkcd.com/982/
# Unregistered from xkcd.com/688/
# Unregistered from xkcd.com/981/
# Unregistered from xkcd.com/689/
# Unregistered from xkcd.com/980/
# Unregistered from xkcd.com/690/
# Unregistered from xkcd.com/979/
# Unregistered from xkcd.com/978/
# Unregistered from xkcd.com/691/
# Unregistered from xkcd.com/977/
# Unregistered from xkcd.com/692/
# Unregistered from xkcd.com/976/
# Unregistered from xkcd.com/693/
# Unregistered from xkcd.com/975/
# Unregistered from xkcd.com/694/
# Unregistered from xkcd.com/974/
# Unregistered from xkcd.com/695/
# Unregistered from xkcd.com/973/
# Unregistered from xkcd.com/696/
# Unregistered from xkcd.com/972/
# Unregistered from xkcd.com/697/
# Unregistered from xkcd.com/971/
# Unregistered from xkcd.com/698/
# Unregistered from xkcd.com/699/
# Unregistered from xkcd.com/970/
# Unregistered from xkcd.com/700/
# Unregistered from xkcd.com/969/
# Unregistered from xkcd.com/701/
# Unregistered from xkcd.com/968/
# Unregistered from xkcd.com/702/
# Unregistered from xkcd.com/967/
# Unregistered from xkcd.com/703/
# Unregistered from xkcd.com/966/
# Unregistered from xkcd.com/704/
# Unregistered from xkcd.com/965/
# Unregistered from xkcd.com/705/
# Unregistered from xkcd.com/964/
# Unregistered from xkcd.com/706/
# Unregistered from xkcd.com/963/
# Unregistered from xkcd.com/707/
# Unregistered from xkcd.com/962/
# Unregistered from xkcd.com/708/
# Unregistered from xkcd.com/961/
# Unregistered from xkcd.com/709/
# Unregistered from xkcd.com/960/
# Unregistered from xkcd.com/710/
# Unregistered from xkcd.com/959/
# Unregistered from xkcd.com/711/
# Unregistered from xkcd.com/958/
# Unregistered from xkcd.com/957/
# Unregistered from xkcd.com/712/
# Unregistered from xkcd.com/956/
# Unregistered from xkcd.com/713/
# Unregistered from xkcd.com/955/
# Unregistered from xkcd.com/714/
# Unregistered from xkcd.com/954/
# Unregistered from xkcd.com/715/
# Unregistered from xkcd.com/953/
# Unregistered from xkcd.com/716/
# Unregistered from xkcd.com/952/
# Unregistered from xkcd.com/717/
# Unregistered from xkcd.com/951/
# Unregistered from xkcd.com/718/
# Unregistered from xkcd.com/950/
# Unregistered from xkcd.com/719/
# Unregistered from xkcd.com/949/
# Unregistered from xkcd.com/720/
# Unregistered from xkcd.com/948/
# Unregistered from xkcd.com/721/
# Unregistered from xkcd.com/947/
# Unregistered from xkcd.com/722/
# Unregistered from xkcd.com/946/
# Unregistered from xkcd.com/723/
# Unregistered from xkcd.com/945/
# Unregistered from xkcd.com/724/
# Unregistered from xkcd.com/944/
# Unregistered from xkcd.com/725/
# Unregistered from xkcd.com/943/
# Unregistered from xkcd.com/726/
# Unregistered from xkcd.com/942/
# Unregistered from xkcd.com/727/
# Unregistered from xkcd.com/941/
# Unregistered from xkcd.com/940/
# Unregistered from xkcd.com/728/
# Unregistered from xkcd.com/939/
# Unregistered from xkcd.com/729/
# Unregistered from xkcd.com/938/
# Unregistered from xkcd.com/730/
# Unregistered from xkcd.com/937/
# Unregistered from xkcd.com/731/
# Unregistered from xkcd.com/732/
# Unregistered from xkcd.com/936/
# Unregistered from xkcd.com/733/
# Unregistered from xkcd.com/935/
# Unregistered from xkcd.com/734/
# Unregistered from xkcd.com/934/
# Unregistered from xkcd.com/735/
# Unregistered from xkcd.com/933/
# Unregistered from xkcd.com/932/
# Unregistered from xkcd.com/736/
# Unregistered from xkcd.com/931/
# Unregistered from xkcd.com/737/
# Unregistered from xkcd.com/930/
# Unregistered from xkcd.com/738/
# Unregistered from xkcd.com/929/
# Unregistered from xkcd.com/739/
# Unregistered from xkcd.com/928/
# Unregistered from xkcd.com/740/
# Unregistered from xkcd.com/927/
# Unregistered from xkcd.com/741/
# Unregistered from xkcd.com/926/
# Unregistered from xkcd.com/742/
# Unregistered from xkcd.com/925/
# Unregistered from xkcd.com/743/
# Unregistered from xkcd.com/924/
# Unregistered from xkcd.com/744/
# Unregistered from xkcd.com/923/
# Unregistered from xkcd.com/745/
# Unregistered from xkcd.com/922/
# Unregistered from xkcd.com/746/
# Unregistered from xkcd.com/921/
# Unregistered from xkcd.com/747/
# Unregistered from xkcd.com/920/
# Unregistered from xkcd.com/748/
# Unregistered from xkcd.com/919/
# Unregistered from xkcd.com/749/
# Unregistered from xkcd.com/918/
# Unregistered from xkcd.com/750/
# Unregistered from xkcd.com/917/
# Unregistered from xkcd.com/751/
# Unregistered from xkcd.com/916/
# Unregistered from xkcd.com/752/
# Unregistered from xkcd.com/915/
# Unregistered from xkcd.com/753/
# Unregistered from xkcd.com/914/
# Unregistered from xkcd.com/754/
# Unregistered from xkcd.com/913/
# Unregistered from xkcd.com/755/
# Unregistered from xkcd.com/912/
# Unregistered from xkcd.com/756/
# Unregistered from xkcd.com/911/
# Unregistered from xkcd.com/757/
# Unregistered from xkcd.com/910/
# Unregistered from xkcd.com/758/
# Unregistered from xkcd.com/909/
# Unregistered from xkcd.com/759/
# Unregistered from xkcd.com/908/
# Unregistered from xkcd.com/760/
# Unregistered from xkcd.com/907/
# Unregistered from xkcd.com/761/
# Unregistered from xkcd.com/906/
# Unregistered from xkcd.com/762/
# Unregistered from xkcd.com/905/
# Unregistered from xkcd.com/763/
# Unregistered from xkcd.com/904/
# Unregistered from xkcd.com/764/
# Unregistered from xkcd.com/903/
# Unregistered from xkcd.com/765/
# Unregistered from xkcd.com/902/
# Unregistered from xkcd.com/766/
# Unregistered from xkcd.com/901/
# Unregistered from xkcd.com/767/
# Unregistered from xkcd.com/900/
# Unregistered from xkcd.com/768/
# Unregistered from xkcd.com/899/
# Unregistered from xkcd.com/769/
# Unregistered from xkcd.com/898/
# Unregistered from xkcd.com/770/
# Unregistered from xkcd.com/897/
# Unregistered from xkcd.com/771/
# Unregistered from xkcd.com/772/
# Unregistered from xkcd.com/896/
# Unregistered from xkcd.com/773/
# Unregistered from xkcd.com/895/
# Unregistered from xkcd.com/774/
# Unregistered from xkcd.com/894/
# Unregistered from xkcd.com/775/
# Unregistered from xkcd.com/893/
# Unregistered from xkcd.com/776/
# Unregistered from xkcd.com/892/
# Unregistered from xkcd.com/891/
# Unregistered from xkcd.com/777/
# Unregistered from xkcd.com/890/
# Unregistered from xkcd.com/778/
# Unregistered from xkcd.com/889/
# Unregistered from xkcd.com/779/
# Unregistered from xkcd.com/888/
# Unregistered from xkcd.com/780/
# Unregistered from xkcd.com/887/
# Unregistered from xkcd.com/781/
# Unregistered from xkcd.com/886/
# Unregistered from xkcd.com/782/
# Unregistered from xkcd.com/885/
# Unregistered from xkcd.com/783/
# Unregistered from xkcd.com/884/
# Unregistered from xkcd.com/784/
# Unregistered from xkcd.com/785/
# Unregistered from xkcd.com/883/
# Unregistered from xkcd.com/786/
# Unregistered from xkcd.com/882/
# Unregistered from xkcd.com/787/
# Unregistered from xkcd.com/881/
# Unregistered from xkcd.com/788/
# Unregistered from xkcd.com/880/
# Unregistered from xkcd.com/789/
# Unregistered from xkcd.com/879/
# Unregistered from xkcd.com/790/
# Unregistered from xkcd.com/878/
# Unregistered from xkcd.com/791/
# Unregistered from xkcd.com/877/
# Unregistered from xkcd.com/792/
# Unregistered from xkcd.com/876/
# Unregistered from xkcd.com/793/
# Unregistered from xkcd.com/875/
# Unregistered from xkcd.com/794/
# Unregistered from xkcd.com/874/
# Unregistered from xkcd.com/795/
# Unregistered from xkcd.com/873/
# Unregistered from xkcd.com/796/
# Unregistered from xkcd.com/872/
# Unregistered from xkcd.com/797/
# Unregistered from xkcd.com/871/
# Unregistered from xkcd.com/798/
# Unregistered from xkcd.com/870/
# Unregistered from xkcd.com/799/
# Unregistered from xkcd.com/869/
# Unregistered from xkcd.com/800/
# Unregistered from xkcd.com/868/
# Unregistered from xkcd.com/801/
# Unregistered from xkcd.com/867/
# Unregistered from xkcd.com/802/
# Unregistered from xkcd.com/866/
# Unregistered from xkcd.com/803/
# Unregistered from xkcd.com/865/
# Unregistered from xkcd.com/804/
# Unregistered from xkcd.com/864/
# Unregistered from xkcd.com/805/
# Unregistered from xkcd.com/863/
# Unregistered from xkcd.com/806/
# Unregistered from xkcd.com/862/
# Unregistered from xkcd.com/807/
# Unregistered from xkcd.com/808/
# Unregistered from xkcd.com/861/
# Unregistered from xkcd.com/809/
# Unregistered from xkcd.com/860/
# Unregistered from xkcd.com/810/
# Unregistered from xkcd.com/859/
# Unregistered from xkcd.com/858/
# Unregistered from xkcd.com/811/
# Unregistered from xkcd.com/857/
# Unregistered from xkcd.com/812/
# Unregistered from xkcd.com/856/
# Unregistered from xkcd.com/813/
# Unregistered from xkcd.com/855/
# Unregistered from xkcd.com/814/
# Unregistered from xkcd.com/854/
# Unregistered from xkcd.com/815/
# Unregistered from xkcd.com/853/
# Unregistered from xkcd.com/816/
# Unregistered from xkcd.com/852/
# Unregistered from xkcd.com/817/
# Unregistered from xkcd.com/851/
# Unregistered from xkcd.com/818/
# Unregistered from xkcd.com/850/
# Unregistered from xkcd.com/819/
# Unregistered from xkcd.com/849/
# Unregistered from xkcd.com/820/
# Unregistered from xkcd.com/848/
# Unregistered from xkcd.com/821/
# Unregistered from xkcd.com/847/
# Unregistered from xkcd.com/822/
# Unregistered from xkcd.com/823/
# Unregistered from xkcd.com/846/
# Unregistered from xkcd.com/824/
# Unregistered from xkcd.com/845/
# Unregistered from xkcd.com/844/
# Unregistered from xkcd.com/825/
# Unregistered from xkcd.com/843/
# Unregistered from xkcd.com/826/
# Unregistered from xkcd.com/842/
# Unregistered from xkcd.com/827/
# Unregistered from xkcd.com/841/
# Unregistered from xkcd.com/828/
# Unregistered from xkcd.com/840/
# Unregistered from xkcd.com/829/
# Unregistered from xkcd.com/839/
# Unregistered from xkcd.com/838/
# Unregistered from xkcd.com/830/
# Unregistered from xkcd.com/831/
# Unregistered from xkcd.com/837/
# Unregistered from xkcd.com/832/
# Unregistered from xkcd.com/836/
# Unregistered from xkcd.com/833/
# Unregistered from xkcd.com/835/
# Unregistered from xkcd.com/834/

# %%
# The number of urls we saw
print(len(seen_urls))
# Out:
# 1675
